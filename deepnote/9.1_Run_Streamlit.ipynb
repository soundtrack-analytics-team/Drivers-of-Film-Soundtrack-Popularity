# %%
from IPython.core.display import HTML
import os

# %%
display(HTML(f'<h2><a href="https://{os.environ["DEEPNOTE_PROJECT_ID"]}.deepnoteproject.com" target="_blank">Click here</a> to open Streamlit</h2>'))
print(f"https://" + os.environ["DEEPNOTE_PROJECT_ID"] + ".deepnoteproject.com")
# Out:
# <h2><a href="https://b124131d-2024-4253-bb46-8043aed4b78f.deepnoteproject.com" target="_blank">Click here</a> to open Streamlit</h2>
# https://b124131d-2024-4253-bb46-8043aed4b78f.deepnoteproject.com

# %%
# !streamlit run /work/SIADS_593_Drivers_of_Soundtrack_Streaming_Performance/streamlit/demo.py --server.port=8080 --browser.serverAddress='0.0.0.0'
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8080
#
# ^C
#   Stopping...

# %%
import streamlit as st
st.title("Test")
st.write("If this loads, your main app has an error.")
# Out:
# 2026-02-25 23:44:10.944 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 23:44:13.724
# ...
#   command:
#
#     streamlit run /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-25 23:44:13.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 23:44:13.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 23:44:13.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 23:44:13.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !streamlit run streamlit/demo.py --server.address=0.0.0.0 --server.port=8501 --server.headless=true
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.244.13.30:8501
#   External URL: http://168.119.35.151:8501
#
# ^C
#   Stopping...

# %%
display(HTML(f'<h2><a href="https://{os.environ["DEEPNOTE_PROJECT_ID"]}.deepnoteproject.com" target="_blank">Click here</a> to open Streamlit</h2>'))
print(f"https://" + os.environ["DEEPNOTE_PROJECT_ID"] + ".deepnoteproject.com")
# Out:
# <h2><a href="https://b124131d-2024-4253-bb46-8043aed4b78f.deepnoteproject.com" target="_blank">Click here</a> to open Streamlit</h2>
# https://b124131d-2024-4253-bb46-8043aed4b78f.deepnoteproject.com

# %%
# !curl http://10.244.13.30:8501 or !wget -O- http://10.244.13.30:8501
# Out:
# curl: option -O-: is unknown
# curl: try 'curl --help' or 'curl --manual' for more information

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b124131d-2024-4253-bb46-8043aed4b78f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
