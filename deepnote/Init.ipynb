# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting spotipy==2.25.2 (from -r ./requirements.txt (line 2))
#   Downloading spotipy-2.25.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting ftfy==6.3.1 (from -r ./requirements.txt (line 3))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting python-dotenv==1.2.1 (from -r ./requirements.txt (line 6))
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting bs4==0.0.2 (from -r ./requirements.txt (line 7))
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting altair<6 (from -r ./requirements.txt (line 8))
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting statsmodels==0.14.6 (from -r ./requirements.txt (line 15))
#   Downloading statsmodels-0.14.6-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting streamlit (from -r ./requirements.txt (line 16))
#   Downloading streamlit-1.54.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting redis>=3.5.3 (from spotipy==2.25.2->-r ./requirements.txt (line 2))
#   Downloading redis-7.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.25.0 in /root/venv/lib/python3.11/site-packages (from spotipy==2.25.2->-r ./requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in /root/venv/lib/python3.11/site-packages (from spotipy==2.25.2->-r ./requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.11/site-packages (from ftfy==6.3.1->-r ./requirements.txt (line 3)) (0.6.0)
# Collecting beautifulsoup4 (from bs4==0.0.2->-r ./requirements.txt (line 7))
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /root/venv/lib/python3.11/site-packages (from statsmodels==0.14.6->-r ./requirements.txt (line 15)) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /root/venv/lib/python3.11/site-packages (from statsmodels==0.14.6->-r ./requirements.txt (line 15)) (1.11.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /root/venv/lib/python3.11/site-packages (from statsmodels==0.14.6->-r ./requirements.txt (line 15)) (2.1.4)
# Collecting patsy>=0.5.6 (from statsmodels==0.14.6->-r ./requirements.txt (line 15))
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.11/site-packages (from statsmodels==0.14.6->-r ./requirements.txt (line 15)) (26.0)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.11/site-packages (from altair<6->-r ./requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from altair<6->-r ./requirements.txt (line 8)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /root/venv/lib/python3.11/site-packages (from altair<6->-r ./requirements.txt (line 8)) (2.16.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /root/venv/lib/python3.11/site-packages (from altair<6->-r ./requirements.txt (line 8)) (4.15.0)
# Collecting blinker<2,>=1.5.0 (from streamlit->-r ./requirements.txt (line 16))
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<7,>=5.5 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /root/venv/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (8.3.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r ./requirements.txt (line 16))
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pillow<13,>=7.1.0 in /root/venv/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (12.1.1)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r ./requirements.txt (line 16))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in /root/venv/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (4.25.8)
# Requirement already satisfied: pyarrow>=7.0 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (16.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit->-r ./requirements.txt (line 16)) (6.5.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit->-r ./requirements.txt (line 16))
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 5.7 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ./requirements.txt (line 16))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /root/venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6->-r ./requirements.txt (line 8)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6->-r ./requirements.txt (line 8)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6->-r ./requirements.txt (line 8)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /toolkit-cache/2.1.2/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6->-r ./requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.6->-r ./requirements.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.6->-r ./requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.6->-r ./requirements.txt (line 15)) (2025.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.11/site-packages (from jinja2->altair<6->-r ./requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests>=2.25.0->spotipy==2.25.2->-r ./requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.11/site-packages (from requests>=2.25.0->spotipy==2.25.2->-r ./requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.11/site-packages (from requests>=2.25.0->spotipy==2.25.2->-r ./requirements.txt (line 2)) (2026.1.4)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4==0.0.2->-r ./requirements.txt (line 7))
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ./requirements.txt (line 16))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels==0.14.6->-r ./requirements.txt (line 15)) (1.17.0)
# Downloading spotipy-2.25.2-py3-none-any.whl (31 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading statsmodels-0.14.6-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 89.4 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 68.4 MB/s eta 0:00:00
# Downloading streamlit-1.54.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 97.4 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 kB 28.0 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 31.9 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 96.1 MB/s eta 0:00:00
# Downloading redis-7.2.1-py3-none-any.whl (396 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.1/396.1 kB 47.2 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 11.0 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 19.9 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.5 MB/s eta 0:00:00
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, soupsieve, smmap, redis, python-dotenv, patsy, ftfy, blinker, spotipy, pydeck, gitdb, beautifulsoup4, statsmodels, gitpython, bs4, altair, streamlit
# Successfully installed altair-5.5.0 beautifulsoup4-4.14.3 blinker-1.9.0 bs4-0.0.2 ftfy-6.3.1 gitdb-4.0.12 gitpython-3.1.46 patsy-1.0.2 pydeck-0.9.1 python-dotenv-1.2.1 redis-7.2.1 smmap-5.0.2 soupsieve-2.8.3 spotipy-2.25.2 statsmodels-0.14.6 streamlit-1.54.0 watchdog-6.0.0
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b124131d-2024-4253-bb46-8043aed4b78f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
