# %% [markdown]
# # I\. Setup and Album Title Inspection

# %%
# Standard library imports
import os
from datetime import datetime

# Third-party imports
import numpy as np
import pandas as pd

# SETUP & CONFIGURATION
os.chdir("/work")
print(os.listdir("./pipeline"))

# Show all columns (no truncation)
pd.set_option("display.max_columns", None)
# Out:
# ['1.1.TMDB 2015-2025.csv', '2.2.MUSICBRAINZ_mv_tmdb_soundtrack_album_artist_bridge_2015_2025.csv', '2.2.MUSICBRAINZ_mv_tmdb_soundtrack_artist_spine_2015_2025.csv', '3.2.Albums_official_df.csv', '3.2.Artists_official_df.csv', '3.2.Tracks_official_df.csv', '3.2.Wide_official_df.csv', '3.3.Albums_deduped_df.csv', '3.3.Artists_deduped_df.csv', '3.3.Tracks_deduped_df.csv', '3.3.Wide_deduped_df.csv', '3.4.Albums_canonical_identified_df.csv', '3.4.Artists_canonical_identified_df.csv', '3.4.Tracks_canonical_identified_df.csv', '3.4.Wide_canonical_identified_df.csv', '3.5.Albums_exploded_genre.csv', '3.5.Artists_exploded_genre.csv', '3.5.Tracks_exploded_genre.csv', '3.5.Wide_exploded_genre.csv', '3.6.Albums_vote_count_analysis.csv', '3.6.Artists_vote_count_analysis.csv', '3.6.Tracks_vote_count_analysis.csv', '3.6.Wide_vote_count_analysis.csv', '3.7.Albums_composer_analysis.csv', '3.7.Artists_composer_analysis.csv', '3.7.Tracks_composer_analysis.csv', '3.7.Wide_composer_analysis.csv', '4.1.1.Albums_awards_appended.csv', '4.1.1.Artists_awards_appended.csv', '4.1.1.Tracks_awards_appended.csv', '4.1.1.Wide_awards_appended.csv', '4.1.All_Awards_2015_2025.csv', '4.2.Albums_lastfm_appended.csv', '4.2.Artists_lastfm_appended.csv', '4.2.Tracks_lastfm_appended.csv', '4.2.Tracks_lastfm_augmentation.csv.for_deletion', '4.2.Wide_lastfm_appended.csv', '4.2.Wide_lastfm_augmentation.csv_for_deletion', '4.3.Albums_spotify_ids.csv', '4.3.Artists_spotify_ids.csv', '4.3.Tracks_spotify_ids.csv', '4.3.Wide_spotify_ids.csv', '4.4.Albums_rapid_api_pull.csv', '4.4.Artists_rapid_api_pull.csv', '4.4.Tracks_rapid_api_pull.csv', '4.4.Wide_rapid_api_pull.csv', '4.5.Albums_join_everything.csv', '4.5.Artists_join_everything.csv', '4.5.Tracks_join_everything.csv', '4.5.Wide_join_everything.csv', '4.7.Albums_analytics_set.csv', '4.7.Artists_analytics_set.csv', '4.7.Tracks_analytics_set.csv', '4.7.Wide_analytics_set.csv', '5.4.a.Tracks_clean.csv', '5.4.b.Tracks_tempo_composer_clean.csv', '5.5.Albums_for_final_viz.csv', 'TMDB_Final_Recovery.csv', '2.1.MUSICBRAINZ_mv_tmdb_soundtrack_album_spine_2015_2025.csv', '2.2.MUSICBRAINZ_mv_tmdb_soundtrack_wide_track_2015_2025.csv', '2.2.MUSICBRAINZ_mv_tmdb_soundtrack_track_spine_2015_2025.csv']

# %%
# Load the albums dataframe

album_df = pd.read_csv("./pipeline/2.1.MUSICBRAINZ_mv_tmdb_soundtrack_album_spine_2015_2025.csv")

# Display initial data inspection
display(album_df.head())
display(album_df.columns)
# Out:
#    tmdb_id                    film_title  film_adult  film_runtime_min  \
# 0   216015          Fifty Shades of Grey       False               125
# 1   216015          Fifty Shades of Grey       False               125
# 2   150689                    Cinderella       False               105
# 3   281957                  The Revenant       False               157
# 4   140607  Star Wars: The Force Awakens       False               136
#
#                           film_genres  film_rating  film_vote_count  \
# 0            Drama, Romance, Thriller        5.875            12222
# 1            Drama, Romance, Thriller        5.875            12222
# 2     Romance, Fantasy, Family, Drama        6.826             7294
# 3           Western, Drama, Adventure        7.540            18928
# 4  Adventure, Action, Science Fiction        7.300            20206
#
#   film_mpaa_rating           film_original_title film_language_name  \
# 0                R          Fifty Shades of Grey            English
# 1                R          Fifty Shades of Grey            English
# 2               PG                    Cinderella            English
# 3                R                  The Revenant            English
# 4            PG-13  Star Wars: The Force Awakens            English
#
#   film_imdb_id film_wikidata_id  \
# 0    tt2322441        Q14566553
# 1    tt2322441        Q14566553
# 2    tt1661199        Q15046091
# 3    tt1663202        Q18002795
# 4    tt2488496            Q6074
#
#                                       film_countries  film_year  \
# 0                           United States of America       2015
# 1                           United States of America       2015
# 2          United Kingdom / United States of America       2015
# 3  Canada / Hong Kong / Taiwan / United States of...       2015
# 4                           United States of America       2015
#
#   film_release_date  film_popularity  film_budget  film_revenue  \
# 0        2015-02-11          18.4171     40000000     569651467
# 1        2015-02-11          18.4171     40000000     569651467
# 2        2015-03-06          11.8041     95000000     543514353
# 3        2015-12-25          10.1655    135000000     532950503
# 4        2015-12-15          10.1330    245000000    2068223624
#
#                                         film_studios  \
# 0  Universal Pictures, Focus Features, Michael De...
# 1  Universal Pictures, Focus Features, Michael De...
# 2  Walt Disney Pictures, Genre Films, Beagle Pug ...
# 3  Monarchy Enterprises S.a.r.l., Regency Enterpr...
# 4                          Lucasfilm Ltd., Bad Robot
#
#                  film_director              film_soundtrack_composer_raw  \
# 0           Sam Taylor-Johnson  Danny Elfman, Ellie Goulding, The Weeknd
# 1           Sam Taylor-Johnson  Danny Elfman, Ellie Goulding, The Weeknd
# 2              Kenneth Branagh                             Patrick Doyle
# 3  Alejandro González Iñárritu               Ryuichi Sakamoto, Alva Noto
# 4                  J.J. Abrams                             John Williams
#
#                                        film_top_cast  \
# 0  Dakota Johnson, Jamie Dornan, Jennifer Ehle, E...
# 1  Dakota Johnson, Jamie Dornan, Jennifer Ehle, E...
# 2  Lily James, Cate Blanchett, Richard Madden, St...
# 3  Leonardo DiCaprio, Tom Hardy, Domhnall Gleeson...
# 4  Harrison Ford, Mark Hamill, Carrie Fisher, Ada...
#
#                                        film_keywords  \
# 0  bad smell, based on novel or book, eroticism, ...
# 1  bad smell, based on novel or book, eroticism, ...
# 2        magic, kingdom, fairy tale, prince, royalty
# 3  rape, based on novel or book, parent child rel...
# 4           android, spacecraft, space opera, absurd
#
#                 film_ingested_at match_method soundtrack_type  notes  \
# 0  2026-01-19 01:36:05.016 -0500   imdb_exact           songs    NaN
# 1  2026-01-19 01:36:05.016 -0500   imdb_exact           score    NaN
# 2  2026-01-19 01:36:05.016 -0500   imdb_exact         unknown    NaN
# 3  2026-01-19 01:36:05.016 -0500   imdb_exact           songs    NaN
# 4  2026-01-19 01:36:05.016 -0500   imdb_exact           songs    NaN
#
#                       matched_at  release_group_id  \
# 0  2026-01-25 02:45:25.371 -0500           1479583
# 1  2026-01-25 02:45:25.371 -0500           1494030
# 2  2026-01-25 02:45:25.371 -0500           1504629
# 3  2026-01-25 02:45:25.371 -0500           1605141
# 4  2026-01-25 02:45:25.371 -0500           1563177
#
#                      release_group_mbid  \
# 0  85852629-ce4c-4bb8-8d4a-50299d56a06c
# 1  fa7aa3a0-3de5-4273-bbb4-cfc13dbf9f1e
# 2  412fdd65-c3f8-40fe-a420-8b438e048915
# 3  5d5a40d3-8aab-41a8-8cfb-b97688a5c10c
# 4  405fd3c5-0a45-456a-b853-6f734d3b57aa
#
#                                          album_title rg_primary_type  \
# 0  Fifty Shades of Grey: Original Motion Picture ...           Album
# 1  Fifty Shades of Grey: Original Motion Picture ...           Album
# 2                                         Cinderella           Album
# 3   The Revenant: Original Motion Picture Soundtrack           Album
# 4  Star Wars: The Force Awakens: Original Motion ...           Album
#
#   rg_secondary_types  release_id                          release_mbid  \
# 0         Soundtrack   1548281.0  bdcaa988-1e80-446b-8e15-39b42255c4ed
# 1         Soundtrack   1566447.0  dd34d90a-52ff-445c-8221-d03a6f876b24
# 2         Soundtrack   1579787.0  5da9400f-7f0c-45f3-8e78-fe98f17aa43e
# 3         Soundtrack   1708615.0  bfff43a0-cac1-460a-94b9-fb10f70806c1
# 4         Soundtrack   1654335.0  7f6687c0-daef-4a1a-aec5-b6edd1f3c7db
#
#                                        release_title release_status  \
# 0  Fifty Shades of Grey: Original Motion Picture ...       Official
# 1  Fifty Shades of Grey: Original Motion Picture ...       Official
# 2                                         Cinderella       Official
# 3   The Revenant: Original Motion Picture Soundtrack       Official
# 4  Star Wars: The Force Awakens: Original Motion ...       Official
#
#   release_packaging       barcode release_language release_script  \
# 0               NaN  6.025472e+11          English          Latin
# 1        Jewel Case  6.025472e+11          English          Latin
# 2               NaN           NaN          English          Latin
# 3               NaN           NaN          English          Latin
# 4           Digipak  5.008732e+10          English          Latin
#
#   release_comment album_us_release_date  album_us_release_year  \
# 0             NaN            2015-02-10                 2015.0
# 1             NaN            2015-02-17                 2015.0
# 2             NaN            2015-03-10                 2015.0
# 3             NaN            2015-12-25                 2015.0
# 4         Digipak            2015-01-01                 2015.0
#
#    album_us_release_month_min_observed  album_us_release_day_min_observed  \
# 0                                  2.0                               10.0
# 1                                  2.0                               17.0
# 2                                  3.0                               10.0
# 3                                 12.0                               25.0
# 4                                  NaN                                NaN
#
#   us_date_has_missing_month us_date_has_missing_day  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                      True                    True
#
#   us_any_event_missing_month us_any_event_missing_day  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                       True                     True
#
#                                         rg_tags_text  \
# 0  contemporary r&b | pop | blues | contemporary ...
# 1                                              score
# 2                             classical | film score
# 3           score | ambient | classical | soundtrack
# 4  soundtrack | film score | score | classical | ...
#
#                                  release_tags_text  \
# 0                                       soundtrack
# 1                                              NaN
# 2                                       film score
# 3                               score | soundtrack
# 4  soundtrack | classical | film score | star wars
#
#                             label_names  \
# 0  Republic Records | Universal Studios
# 1          Republic Records | Universal
# 2                   Walt Disney Records
# 3                                 Milan
# 4                   Walt Disney Records
#
#                                          label_mbids  \
# 0  9e4d8965-4fa4-4ce9-a48a-6db90769aa05 | e0ecd90...
# 1  1391bdc7-a22c-48a4-a5fb-e7b8ef6ce143 | e0ecd90...
# 2               1c50034a-5c92-41a4-95ad-0acb7ea4686f
# 3               41099e29-7301-4fa3-86a4-8d510157b275
# 4               1c50034a-5c92-41a4-95ad-0acb7ea4686f
#
#                                      label_tags_text  rg_rating  \
# 0                                                NaN        NaN
# 1  alejandra guzman | clean up | es 2003 | sólo e...        NaN
# 2  score | soundtrack | soundtrack label | classi...        NaN
# 3  burbank | california | clean up | score | soun...        NaN
# 4  score | soundtrack | soundtrack label | classi...       93.0
#
#    rg_rating_count        release_meta_date_added  \
# 0              NaN  2015-01-09 19:01:19.035 -0500
# 1              NaN  2015-02-16 09:22:51.239 -0500
# 2              NaN  2015-03-16 23:29:40.780 -0400
# 3              NaN  2015-12-31 15:04:24.681 -0500
# 4              3.0  2015-09-04 14:24:34.396 -0400
#
#                           release_meta_info_url release_meta_amazon_asin  \
# 0  https://www.amazon.com/gp/product/B00S17FT82                      NaN
# 1  https://www.amazon.com/gp/product/B00S9303ZM               B00S9303ZM
# 2  https://www.amazon.com/gp/product/B00THRE5TO               B00THRE5TO
# 3  https://www.amazon.com/gp/product/B018THTR7M               B018THTR7M
# 4  https://www.amazon.com/gp/product/B014V6JIQK               B014V6JIQK
#
#   release_meta_cover_art_presence
# 0                         present
# 1                         present
# 2                         present
# 3                         present
# 4                         present
# Index(['tmdb_id', 'film_title', 'film_adult', 'film_runtime_min',
#        'film_genres', 'film_rating', 'film_vote_count', 'film_mpaa_rating',
#        'film_original_title', 'film_language_name', 'film_imdb_id',
#        'film_wikidata_id', 'film_countries', 'film_year', 'film_release_date',
#        'film_popularity', 'film_budget', 'film_revenue', 'film_studios',
#        'film_director', 'film_soundtrack_composer_raw', 'film_top_cast',
#        'film_keywords', 'film_ingested_at', 'match_method', 'soundtrack_type',
#        'notes', 'matched_at', 'release_group_id', 'release_group_mbid',
#        'album_title', 'rg_primary_type', 'rg_secondary_types', 'release_id',
#        'release_mbid', 'release_title', 'release_status', 'release_packaging',
#        'barcode', 'release_language', 'release_script', 'release_comment',
#        'album_us_release_date', 'album_us_release_year',
#        'album_us_release_month_min_observed',
#        'album_us_release_day_min_observed', 'us_date_has_missing_month',
#        'us_date_has_missing_day', 'us_any_event_missing_month',
#        'us_any_event_missing_day', 'rg_tags_text', 'release_tags_text',
#        'label_names', 'label_mbids', 'label_tags_text', 'rg_rating',
#        'rg_rating_count', 'release_meta_date_added', 'release_meta_info_url',
#        'release_meta_amazon_asin', 'release_meta_cover_art_presence'],
#       dtype='object')

# %% [markdown]
# # II\. Unofficial Album Exploration

# %%
# =========================
# Inspect + summarize "unofficial" albums (by release_status)
# Assumes: album_df exists
# =========================

# 1) Quick coverage: how many rows + how many unique release_groups by status?
status_cols = ["release_status", "release_group_mbid", "album_title", "tmdb_id", "film_title", "film_year", "album_us_release_date"]

# Make sure the key columns exist (won't error if some are missing)
status_cols = [c for c in status_cols if c in album_df.columns]

print("Rows in album_df:", len(album_df))
print("\nRelease status distribution (rows):")
display(album_df["release_status"].fillna("(missing)").value_counts(dropna=False))

# Unique release_groups per status
rg_per_status = (
    album_df.assign(release_status=album_df["release_status"].fillna("(missing)"))
           .groupby("release_status")["release_group_mbid"]
           .nunique()
           .sort_values(ascending=False)
           .to_frame("unique_release_groups")
)
print("\nRelease status distribution (unique release_group_mbid):")
display(rg_per_status)
# Out:
# Rows in album_df: 5209
#
# Release status distribution (rows):
# release_status
# Official          5036
# (missing)           89
# Bootleg             53
# Promotion           19
# Withdrawn            7
# Pseudo-Release       5
# Name: count, dtype: int64
# Release status distribution (unique release_group_mbid):
#                 unique_release_groups
# release_status
# Official                         4785
# (missing)                          77
# Bootleg                            39
# Promotion                          15
# Withdrawn                           7
# Pseudo-Release                      5

# %%
# 2) Define what's "unofficial" (everything except Official)
album_df["release_status_clean"] = album_df["release_status"].fillna("(missing)")
unofficial_df = album_df.loc[album_df["release_status_clean"] != "Official"].copy()

print("\nUnofficial rows:", len(unofficial_df))
print("Unofficial unique release_group_mbids:", unofficial_df["release_group_mbid"].nunique())
print("Unofficial unique tmdb_ids:", unofficial_df["tmdb_id"].nunique())
# Out:
# Unofficial rows: 173
# Unofficial unique release_group_mbids: 143
# Unofficial unique tmdb_ids: 171

# %%
# 3) Breakdown of unofficial types (rows + unique release_groups)
unofficial_breakdown = (
    unofficial_df.groupby("release_status_clean")
                 .agg(
                     row_ct=("release_group_mbid", "size"),
                     unique_release_groups=("release_group_mbid", "nunique"),
                     unique_tmdb_ids=("tmdb_id", "nunique"),
                 )
                 .sort_values(["unique_release_groups", "row_ct"], ascending=False)
)
print("\nUnofficial breakdown:")
display(unofficial_breakdown)
# Out:
# Unofficial breakdown:
#                       row_ct  unique_release_groups  unique_tmdb_ids
# release_status_clean
# (missing)                 89                     77               88
# Bootleg                   53                     39               52
# Promotion                 19                     15               19
# Withdrawn                  7                      7                7
# Pseudo-Release             5                      5                5

# %% [markdown]
# Findings: This breakdown confirms that the vast majority of records in the MusicBrainz export are standard releases, with only a small fraction flagged as bootlegs, promotions, withdrawn titles, or pseudo\-releases\. In other words, edge\-case release types exist, but they are not materially driving the dataset\. That gives us confidence that our album spine is largely composed of legitimate commercial soundtrack releases rather than archival artifacts or non\-standard entries\.

# %%
# 4) How much would we drop if we filter them out?
total_rgs = album_df["release_group_mbid"].nunique()
unofficial_rgs = unofficial_df["release_group_mbid"].nunique()

print("\nImpact if we remove unofficial:")
print(f"- % of rows dropped: {len(unofficial_df) / len(album_df):.2%}")
print(f"- % of unique release_groups dropped: {unofficial_rgs / total_rgs:.2%}")
# Out:
# Impact if we remove unofficial:
# - % of rows dropped: 3.32%
# - % of unique release_groups dropped: 2.90%

# %%
# 5) Spot-check: show a few examples per unofficial status
# (useful for sanity-checking what kinds of albums these are)
cols_for_view = ["release_status_clean", "album_title", "release_group_mbid", "rg_primary_type",
                            "album_us_release_date", "release_status", "release_packaging",
                            "rg_tags_text", "label_names", "match_method",
                            "film_title", "film_year", "tmdb_id"
                            ]

for status in unofficial_df["release_status_clean"].value_counts().index:
    print(f"\n--- Examples: {status} ---")
    display(
        unofficial_df.loc[unofficial_df["release_status_clean"] == status, cols_for_view]
                    .drop_duplicates(subset=[c for c in ["release_group_mbid", "tmdb_id"] if c in unofficial_df.columns])
                    .head(15)
    )
# Out:
# --- Examples: (missing) ---
#      release_status_clean                                        album_title  \
# 45              (missing)          Vice (Original Motion Picture Soundtrack)
# 212             (missing)                                              Wings
# 538             (missing)                           Ma Rainey's Black Bottom
# 915             (missing)                             Mudhal Nee Mudivum Nee
# 918             (missing)                                              Limbo
# 919             (missing)                                              Limbo
# 953             (missing)                             Fake News (Soundtrack)
# 975             (missing)  We Are Still Here (Original Motion Picture Sou...
# 1020            (missing)                                             Heaven
# 1053            (missing)                             Good Night, Knight OST
# 1061            (missing)  London Has Fallen (Official Motion Picture Sou...
# 1107            (missing)                                              Wings
# 1116            (missing)                                 Knock-knock OST EP
# 1163            (missing)                                              Jaanu
# 1176            (missing)                                 Gauthamante Radham
#
#                         release_group_mbid rg_primary_type  \
# 45    677c466b-e852-4350-b375-970c449d4a0a           Album
# 212   3045b83b-5014-49ec-ac78-03893ce5991a          Single
# 538   ca267058-e26f-4db9-8b42-145b0f8ca489           Album
# 915   c6ac7ec7-fcda-412e-b13c-301949c08e25           Album
# 918   14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 919   14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 953   785004df-433c-4537-b1f4-4fa7907bdf2d           Album
# 975   065a3a89-1fd2-4482-b73f-24a4d8dee4b7           Album
# 1020  bccfef28-9f1d-44e6-ae00-5cfdb34d836f             NaN
# 1053  514437dc-d0f8-4b91-93d2-e6795fdfa38a           Album
# 1061  709ec3e7-4d88-4f41-83e5-37e738296418           Album
# 1107  3045b83b-5014-49ec-ac78-03893ce5991a          Single
# 1116  e5925b60-dbed-431a-a4ba-6da0cda06675              EP
# 1163  796ce7ec-4b15-4ae9-a428-cd243c5f50b8           Album
# 1176  1ad66fcd-3897-4c39-95f0-e2feccafe5d9           Album
#
#      album_us_release_date release_status release_packaging  \
# 45              2015-05-30            NaN               NaN
# 212                    NaN            NaN               NaN
# 538             2020-01-01            NaN               NaN
# 915                    NaN            NaN               NaN
# 918                    NaN            NaN               NaN
# 919                    NaN            NaN               NaN
# 953                    NaN            NaN               NaN
# 975                    NaN            NaN               NaN
# 1020                   NaN            NaN               NaN
# 1053                   NaN            NaN               NaN
# 1061            2016-03-04            NaN               NaN
# 1107                   NaN            NaN               NaN
# 1116                   NaN            NaN               NaN
# 1163                   NaN            NaN               NaN
# 1176                   NaN            NaN               NaN
#
#               rg_tags_text                    label_names  \
# 45    ambient | electronic         Metropolis Movie Music
# 212                    NaN                            NaN
# 538                  blues  Masterworks | Milan | Netflix
# 915                    NaN                            NaN
# 918                    NaN                            NaN
# 919                    NaN                            NaN
# 953                    NaN                            NaN
# 975                    NaN                            NaN
# 1020                   NaN    Umbrella Artist Productions
# 1053                   NaN                            NaN
# 1061                   NaN                 Back Lot Music
# 1107                   NaN                            NaN
# 1116                   NaN                            NaN
# 1163                   NaN                            NaN
# 1176                   NaN                       Muzik247
#
#                match_method                film_title  film_year  tmdb_id
# 45               imdb_exact                      Vice       2015   307663
# 212              imdb_exact             We Are Family       2016   391700
# 538              imdb_exact  Ma Rainey's Black Bottom       2020   615667
# 915   title_contains_strict    Mudhal Nee Mudivum Nee       2022   861996
# 918   title_contains_strict                     Limbo       2019   583755
# 919   title_contains_strict                     Limbo       2020   610908
# 953   title_contains_strict                 Fake News       2021   735716
# 975   title_contains_strict         We Are Still Here       2015   291272
# 1020  title_contains_strict                    Heaven       2018   552362
# 1053  title_contains_strict                Good Night       2023  1090969
# 1061  title_contains_strict         London Has Fallen       2016   267860
# 1107  title_contains_strict                     Wings       2019   628723
# 1116  title_contains_strict               Knock Knock       2021   823526
# 1163  title_contains_strict                     Jaanu       2020   669146
# 1176  title_contains_strict        Gauthamante Radham       2020   667986
# --- Examples: Bootleg ---
#      release_status_clean                                        album_title  \
# 815               Bootleg                                       Night School
# 866               Bootleg                            Guava Island Soundtrack
# 907               Bootleg  Merry Christmas, Data Design (Original Soundtr...
# 908               Bootleg  Merry Christmas, Data Design (Original Soundtr...
# 910               Bootleg                                               Rage
# 911               Bootleg                                               Rage
# 1114              Bootleg                                   The Beast Within
# 1151              Bootleg  My Little Pony: Equestria Girls - Magical Movi...
# 1158              Bootleg                                              Agony
# 1265              Bootleg                                           Among Us
# 1407              Bootleg                                            Area 51
# 1416              Bootleg                                          Evolution
# 1431              Bootleg                                      Endless Night
# 1448              Bootleg                                              Gypsy
# 1449              Bootleg                                              Gypsy
#
#                         release_group_mbid rg_primary_type  \
# 815   67a7e6d3-5eb6-4859-9dfa-6a54c7e13e66           Album
# 866   70d20859-fdc0-4cdd-a035-d9d1e38dd0c1              EP
# 907   9c14143a-9a6f-4dce-8e2f-b0fb74d68e63           Album
# 908   9c14143a-9a6f-4dce-8e2f-b0fb74d68e63           Album
# 910   7f5c32eb-b083-4921-90b2-51344f633cac           Album
# 911   7f5c32eb-b083-4921-90b2-51344f633cac           Album
# 1114  c8ebc3dd-fc3b-479a-af71-090a76fade6e           Album
# 1151  0444e93d-41be-414f-847c-3c9508201c3f           Album
# 1158  860f9004-35df-4c92-af40-c3eb4925c6be           Album
# 1265  535e1cc6-faad-42cf-a1bc-eb2d9f9ad2ec           Other
# 1407  a83329ce-1bba-4bf0-862c-28892612f91a           Album
# 1416  69255f10-e358-35c8-b944-4f1594201e1c           Album
# 1431  a62e4c2b-b680-4803-b4f5-6c4dbade9965           Album
# 1448  808e6afd-eaa2-385a-844a-2155545974b6           Album
# 1449  808e6afd-eaa2-385a-844a-2155545974b6           Album
#
#      album_us_release_date release_status release_packaging    rg_tags_text  \
# 815                    NaN        Bootleg               NaN             NaN
# 866                    NaN        Bootleg               NaN             NaN
# 907                    NaN        Bootleg               NaN             NaN
# 908                    NaN        Bootleg               NaN             NaN
# 910                    NaN        Bootleg               NaN             NaN
# 911                    NaN        Bootleg               NaN             NaN
# 1114                   NaN        Bootleg               NaN             NaN
# 1151                   NaN        Bootleg               NaN             NaN
# 1158                   NaN        Bootleg               NaN             NaN
# 1265                   NaN        Bootleg               NaN      soundtrack
# 1407                   NaN        Bootleg               NaN             NaN
# 1416                   NaN        Bootleg               NaN  easy listening
# 1431                   NaN        Bootleg               NaN             NaN
# 1448                   NaN        Bootleg               NaN             NaN
# 1449                   NaN        Bootleg               NaN             NaN
#
#                         label_names           match_method  \
# 815             The Master Cylinder  title_contains_strict
# 866                             NaN  title_contains_strict
# 907                             NaN  title_contains_strict
# 908                             NaN  title_contains_strict
# 910             The Master Cylinder  title_contains_strict
# 911             The Master Cylinder  title_contains_strict
# 1114                            NaN  title_contains_strict
# 1151                            NaN  title_contains_strict
# 1158  The 16-bit Audiophile Project  title_contains_strict
# 1265                            NaN  title_contains_strict
# 1407                            NaN  title_contains_strict
# 1416                            NaN  title_contains_strict
# 1431            The Master Cylinder  title_contains_strict
# 1448                            NaN  title_contains_strict
# 1449                            NaN  title_contains_strict
#
#                                              film_title  film_year  tmdb_id
# 815                                        Night School       2018   454293
# 866                                        Guava Island       2019   543343
# 907                                     Merry Christmas       2023   894958
# 908                                     Merry Christmas       2024   890116
# 910                                                Rage       2016   359344
# 911                                                Rage       2020   694096
# 1114                                   The Beast Within       2024  1300962
# 1151  My Little Pony: Equestria Girls - Magical Movi...       2017   527429
# 1158                                              Agony       2016   384086
# 1265                                           Among Us       2017   707080
# 1407                                            Area 51       2015    57876
# 1416                                          Evolution       2016   330770
# 1431                                      Endless Night       2019   616225
# 1448                                              Gypsy       2015   374547
# 1449                                              Gypsy       2020   574830
# --- Examples: Promotion ---
#      release_status_clean                                        album_title  \
# 822             Promotion                                            Arsenal
# 865             Promotion                                  Dead in the Water
# 1108            Promotion                                        Playing God
# 1856            Promotion                                          Freestyle
# 1920            Promotion                                       In My Dreams
# 1943            Promotion            Happily Never After Bonus Soundtrack CD
# 3031            Promotion  Star Wars: The Rise of Skywalker: Original Mot...
# 3467            Promotion                                  Dead in the Water
# 3690            Promotion                                        Playing God
# 3691            Promotion                                        Playing God
# 3935            Promotion                                Interlude in Prague
# 3998            Promotion                                        Remember Me
# 4186            Promotion                             MYTH OF MAN Soundtrack
# 4274            Promotion                                          The Abyss
# 4465            Promotion                                          Freestyle
#
#                         release_group_mbid rg_primary_type  \
# 822   b4e6f0f7-ece6-485d-9166-60ac0965514f           Album
# 865   50f4ae05-820a-46fa-b2c5-d308da41640b           Album
# 1108  a0c30f68-9c93-491c-ab91-c8a9dfda57a6           Album
# 1856  28347912-017b-42f8-b1e7-1b12a975291c          Single
# 1920  13539200-9378-4ea5-977b-0e126a8f6fa7           Album
# 1943  0e4c8400-4fd8-4428-a350-891912a966ab           Album
# 3031  e3e74153-b7b0-466e-9e69-b587a5ead9cc           Album
# 3467  50f4ae05-820a-46fa-b2c5-d308da41640b           Album
# 3690  a0c30f68-9c93-491c-ab91-c8a9dfda57a6           Album
# 3691  a0c30f68-9c93-491c-ab91-c8a9dfda57a6           Album
# 3935  5ec26e82-d1d3-4a92-afba-8e1b842af6e2           Album
# 3998  33c8f1b7-8a7b-4b9f-a6c4-d93b3851a85e          Single
# 4186  59d12cae-3fd3-4515-adb3-ed80212c6556           Album
# 4274  bb158dea-c566-4e15-b839-fb9e7401512a             NaN
# 4465  28347912-017b-42f8-b1e7-1b12a975291c          Single
#
#      album_us_release_date release_status       release_packaging  \
# 822                    NaN      Promotion  Cardboard/Paper Sleeve
# 865                    NaN      Promotion                     NaN
# 1108                   NaN      Promotion                     NaN
# 1856                   NaN      Promotion                   Other
# 1920            2014-01-01      Promotion                 Digipak
# 1943                   NaN      Promotion                     NaN
# 3031            2019-01-01      Promotion                     NaN
# 3467                   NaN      Promotion                     NaN
# 3690                   NaN      Promotion                     NaN
# 3691                   NaN      Promotion                     NaN
# 3935                   NaN      Promotion  Cardboard/Paper Sleeve
# 3998            2018-01-01      Promotion                     NaN
# 4186                   NaN      Promotion                     NaN
# 4274                   NaN      Promotion          Discbox Slider
# 4465                   NaN      Promotion                   Other
#
#                                            rg_tags_text           label_names  \
# 822                                          electronic     I Own You Records
# 865                                                 NaN            [no label]
# 1108                                                NaN            [no label]
# 1856                                                NaN                   NaN
# 1920                                                NaN  Momentum RLP Records
# 1943                                                NaN                   NaN
# 3031  soundtrack | classical | film | film score | o...                   NaN
# 3467                                                NaN            [no label]
# 3690                                                NaN            [no label]
# 3691                                                NaN            [no label]
# 3935                                  classical | opera     Kill City Records
# 3998                                                NaN   Walt Disney Records
# 4186                                                NaN                   NaN
# 4274                                                NaN                   NaN
# 4465                                                NaN                   NaN
#
#                match_method                        film_title  film_year  \
# 822   title_contains_strict                           Arsenal       2017
# 865   title_contains_strict                 Dead in the Water       2018
# 1108  title_contains_strict                       Playing God       2024
# 1856  title_contains_strict                         Freestyle       2022
# 1920  title_contains_strict                      In My Dreams       2015
# 1943  title_contains_strict               Happily Never After       2017
# 3031             imdb_exact  Star Wars: The Rise of Skywalker       2019
# 3467  title_contains_strict                 Dead in the Water       2021
# 3690  title_contains_strict                       Playing God       2020
# 3691  title_contains_strict                       Playing God       2021
# 3935  title_contains_strict               Interlude In Prague       2017
# 3998  title_contains_strict                       Remember Me       2019
# 4186  title_contains_strict                       Myth of Man       2025
# 4274  title_contains_strict                         The Abyss       2023
# 4465  title_contains_strict                         Freestyle       2023
#
#       tmdb_id
# 822    388202
# 865    551910
# 1108  1320467
# 1856   892494
# 1920   266353
# 1943   522328
# 3031   181812
# 3467   786302
# 3690   759930
# 3691   717693
# 3935   458759
# 3998   566675
# 4186  1223275
# 4274  1053544
# 4465  1152797
# --- Examples: Withdrawn ---
#      release_status_clean                                      album_title  \
# 642             Withdrawn      Doctor Strange in the Multiverse of Madness
# 2517            Withdrawn  The Marvels: Original Motion Picture Soundtrack
# 3081            Withdrawn                                Daniel Isn’t Real
# 3227            Withdrawn   The Batman: Original Motion Picture Soundtrack
# 3711            Withdrawn    Smallfoot: Original Motion Picture Soundtrack
# 3851            Withdrawn                 The Runner (Original Soundtrack)
# 4194            Withdrawn                  Rocky Aur Rani Kii Prem Kahaani
#
#                         release_group_mbid rg_primary_type  \
# 642   176b5720-1680-4783-8e94-3046fae2a421           Album
# 2517  4afa8579-467e-4676-a168-5f6494c65c53           Album
# 3081  623e2354-a33c-41b7-9626-109a48be83eb           Album
# 3227  cacbb4e4-0580-4ace-a085-019bc8fe47b1           Album
# 3711  f7b60bd6-6ee1-4d12-a14a-a68d094686e0           Album
# 3851  a997db62-f64c-4aab-8373-f959d685644c           Album
# 4194  d109158e-f445-4cd4-b9b5-843ce748af2b           Album
#
#      album_us_release_date release_status release_packaging  \
# 642             2022-05-04      Withdrawn               NaN
# 2517                   NaN      Withdrawn               NaN
# 3081                   NaN      Withdrawn               NaN
# 3227            2022-02-25      Withdrawn               NaN
# 3711            2018-09-28      Withdrawn               NaN
# 3851            2022-01-01      Withdrawn               NaN
# 4194            2024-05-15      Withdrawn               NaN
#
#                                            rg_tags_text  \
# 642                                           classical
# 2517                                                NaN
# 3081  ambient | classical | electronic | modern clas...
# 3227                     classical | score | soundtrack
# 3711                                                pop
# 3851  electronic | coldwave | drone | ebm | soundtra...
# 4194                                                NaN
#
#                            label_names           match_method  \
# 642   Hollywood Records | Marvel Music             imdb_exact
# 2517                 Hollywood Records  title_contains_strict
# 3081               Deutsche Grammophon             imdb_exact
# 3227                  WaterTower Music             imdb_exact
# 3711                  WaterTower Music  title_contains_strict
# 3851                        City Slang  title_contains_strict
# 4194                          Saregama  title_contains_strict
#
#                                        film_title  film_year  tmdb_id
# 642   Doctor Strange in the Multiverse of Madness       2022   453395
# 2517                                  The Marvels       2023   609681
# 3081                            Daniel Isn't Real       2019   537788
# 3227                                   The Batman       2022   414906
# 3711                                    Smallfoot       2018   446894
# 3851                                   The Runner       2022   887309
# 4194              Rocky Aur Rani Kii Prem Kahaani       2023   848116
# --- Examples: Pseudo-Release ---
#      release_status_clean                           album_title  \
# 1241       Pseudo-Release                     モンスターハンター 狩猟音楽集XX
# 2066       Pseudo-Release                      Perfect Days OST
# 2509       Pseudo-Release                   スタジオジブリ「高畑勲」サントラBOX
# 4376       Pseudo-Release                  ReLIFE オリジナルサウンドトラック
# 4402       Pseudo-Release  Ratchet & Clank: Original Soundtrack
#
#                         release_group_mbid rg_primary_type  \
# 1241  564e9d17-1fb6-4c6b-9235-e8c371e1c7d5           Album
# 2066  8625eb42-0451-45e2-99bb-2d40c503eff4           Album
# 2509  9b710346-ec64-463f-9b09-361d799388ef           Album
# 4376  de655243-3975-4e8a-8b0f-a06fdec8a6b1           Album
# 4402  df81ab43-aa95-411b-b4a3-14095f56030c           Album
#
#      album_us_release_date  release_status release_packaging rg_tags_text  \
# 1241                   NaN  Pseudo-Release        Jewel Case          NaN
# 2066                   NaN  Pseudo-Release               NaN          NaN
# 2509                   NaN  Pseudo-Release               NaN          NaN
# 4376                   NaN  Pseudo-Release               NaN          NaN
# 4402                   NaN  Pseudo-Release               NaN          NaN
#
#                               label_names           match_method  \
# 1241                            SULEPUTER  title_contains_strict
# 2066                                  NaN  title_contains_strict
# 2509                                  NaN  title_contains_strict
# 4376                                  NaN  title_contains_strict
# 4402  Sony Computer Entertainment America  title_contains_strict
#
#            film_title  film_year  tmdb_id
# 1241               XX       2017   297160
# 2066     Perfect Days       2023   976893
# 2509              Box       2015   346757
# 4376           ReLIFE       2017   437620
# 4402  Ratchet & Clank       2016   234004

# %% [markdown]
# Findings: A closer look at non\-standard release\_status categories shows that they are heterogeneous and inconsistently applied\. Many “\(missing\)” entries correspond to legitimate soundtracks, while “Promotion,” “Withdrawn,” and “Pseudo\-Release” statuses often reflect distribution variants, alternate\-language representations, or release\-state artifacts rather than distinct soundtrack concepts\. Because these categories blur structural boundaries at the release\_group level, we opted to anchor the analytical spine exclusively to “Official” releases\. This ensures a clean, reproducible album universe, even if it excludes some edge\-case but potentially valid variants\.

# %%
# 6) Identify the "worst offenders" (unofficial release_groups linked to many films)
# (if you still have dupes around, this can show where unofficial data may be muddying links)
if {"release_group_mbid", "tmdb_id"}.issubset(unofficial_df.columns):
    unofficial_rg_multi = (
        unofficial_df.groupby("release_group_mbid")["tmdb_id"]
                     .nunique()
                     .sort_values(ascending=False)
    )
    print("\nUnofficial release_groups mapped to multiple tmdb_ids (top 20):")
    display(unofficial_rg_multi.head(20).to_frame("distinct_tmdb_ids"))

    # Show context for the top few
    top_unofficial_rgs = unofficial_rg_multi.head(5).index.tolist()
    print("\nContext rows for top unofficial dupes (top 5 release_groups):")
    display(
        unofficial_df.loc[unofficial_df["release_group_mbid"].isin(top_unofficial_rgs), cols_for_view]
                    .sort_values(["release_group_mbid"] + (["film_year"] if "film_year" in cols_for_view else []))
    )
# Out:
# Unofficial release_groups mapped to multiple tmdb_ids (top 20):
#                                       distinct_tmdb_ids
# release_group_mbid
# 14fdc06f-9fbb-47ac-a546-fca0bde66331                  5
# 7f5c32eb-b083-4921-90b2-51344f633cac                  4
# a0c30f68-9c93-491c-ab91-c8a9dfda57a6                  3
# dff756a1-c1a4-4b3e-ba86-282be5d602df                  3
# 2a97a7f8-b9e7-4148-9e8e-753ab4621296                  3
# 535e1cc6-faad-42cf-a1bc-eb2d9f9ad2ec                  2
# 50f4ae05-820a-46fa-b2c5-d308da41640b                  2
# afcb10ed-832b-4b3f-8cd4-82f7a67e76ec                  2
# 69255f10-e358-35c8-b944-4f1594201e1c                  2
# 6e6d0fe6-137b-4217-b651-c151d33e3844                  2
# 3045b83b-5014-49ec-ac78-03893ce5991a                  2
# 28347912-017b-42f8-b1e7-1b12a975291c                  2
# d83ba4b7-4a0e-4c14-ad08-c2ad297b2917                  2
# 22e039fa-ae17-4b2d-85fe-6ece8f988d6e                  2
# 9ea85fb9-3fbc-4158-981e-628d0692811d                  2
# 789368ce-77b9-311b-8a30-cb852d14a414                  2
# bccfef28-9f1d-44e6-ae00-5cfdb34d836f                  2
# 1c19f83e-cf09-410f-9770-a4d328dd6c5d                  2
# 1a9a7e5d-35d2-4f4c-a503-fa134c4843f0                  2
# 9c14143a-9a6f-4dce-8e2f-b0fb74d68e63                  2
# Context rows for top unofficial dupes (top 5 release_groups):
#      release_status_clean    album_title  \
# 918             (missing)          Limbo
# 919             (missing)          Limbo
# 3513            (missing)          Limbo
# 3514            (missing)          Limbo
# 3515            (missing)          Limbo
# 1581            (missing)         INSIDE
# 4204            (missing)         INSIDE
# 4205            (missing)         INSIDE
# 910               Bootleg           Rage
# 3505              Bootleg           Rage
# 911               Bootleg           Rage
# 3506              Bootleg           Rage
# 3690            Promotion    Playing God
# 3691            Promotion    Playing God
# 1108            Promotion    Playing God
# 2388              Bootleg  The Innocents
# 2389              Bootleg  The Innocents
# 2390              Bootleg  The Innocents
#
#                         release_group_mbid rg_primary_type  \
# 918   14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 919   14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 3513  14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 3514  14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 3515  14fdc06f-9fbb-47ac-a546-fca0bde66331             NaN
# 1581  2a97a7f8-b9e7-4148-9e8e-753ab4621296           Album
# 4204  2a97a7f8-b9e7-4148-9e8e-753ab4621296           Album
# 4205  2a97a7f8-b9e7-4148-9e8e-753ab4621296           Album
# 910   7f5c32eb-b083-4921-90b2-51344f633cac           Album
# 3505  7f5c32eb-b083-4921-90b2-51344f633cac           Album
# 911   7f5c32eb-b083-4921-90b2-51344f633cac           Album
# 3506  7f5c32eb-b083-4921-90b2-51344f633cac           Album
# 3690  a0c30f68-9c93-491c-ab91-c8a9dfda57a6           Album
# 3691  a0c30f68-9c93-491c-ab91-c8a9dfda57a6           Album
# 1108  a0c30f68-9c93-491c-ab91-c8a9dfda57a6           Album
# 2388  dff756a1-c1a4-4b3e-ba86-282be5d602df             NaN
# 2389  dff756a1-c1a4-4b3e-ba86-282be5d602df             NaN
# 2390  dff756a1-c1a4-4b3e-ba86-282be5d602df             NaN
#
#      album_us_release_date release_status release_packaging rg_tags_text  \
# 918                    NaN            NaN               NaN          NaN
# 919                    NaN            NaN               NaN          NaN
# 3513                   NaN            NaN               NaN          NaN
# 3514                   NaN            NaN               NaN          NaN
# 3515                   NaN            NaN               NaN          NaN
# 1581                   NaN            NaN               NaN          NaN
# 4204                   NaN            NaN               NaN          NaN
# 4205                   NaN            NaN               NaN          NaN
# 910                    NaN        Bootleg               NaN          NaN
# 3505                   NaN        Bootleg               NaN          NaN
# 911                    NaN        Bootleg               NaN          NaN
# 3506                   NaN        Bootleg               NaN          NaN
# 3690                   NaN      Promotion               NaN          NaN
# 3691                   NaN      Promotion               NaN          NaN
# 1108                   NaN      Promotion               NaN          NaN
# 2388                   NaN        Bootleg               NaN          NaN
# 2389                   NaN        Bootleg               NaN          NaN
# 2390                   NaN        Bootleg               NaN          NaN
#
#               label_names           match_method     film_title  film_year  \
# 918                   NaN  title_contains_strict          Limbo       2019
# 919                   NaN  title_contains_strict          Limbo       2020
# 3513                  NaN  title_contains_strict          Limbo       2020
# 3514                  NaN  title_contains_strict          Limbo       2021
# 3515                  NaN  title_contains_strict          Limbo       2023
# 1581                  NaN  title_contains_strict         Inside       2016
# 4204                  NaN  title_contains_strict         Inside       2023
# 4205                  NaN  title_contains_strict         Inside       2025
# 910   The Master Cylinder  title_contains_strict           Rage       2016
# 3505  The Master Cylinder  title_contains_strict           Rage       2018
# 911   The Master Cylinder  title_contains_strict           Rage       2020
# 3506  The Master Cylinder  title_contains_strict           Rage       2023
# 3690           [no label]  title_contains_strict    Playing God       2020
# 3691           [no label]  title_contains_strict    Playing God       2021
# 1108           [no label]  title_contains_strict    Playing God       2024
# 2388  The Master Cylinder  title_contains_strict  The Innocents       2015
# 2389  The Master Cylinder  title_contains_strict  The Innocents       2016
# 2390  The Master Cylinder  title_contains_strict  The Innocents       2021
#
#       tmdb_id
# 918    583755
# 919    610908
# 3513   554371
# 3514   591222
# 3515  1077670
# 1581   365995
# 4204   958196
# 4205  1225582
# 910    359344
# 3505   510228
# 911    694096
# 3506  1129932
# 3690   759930
# 3691   717693
# 1108  1320467
# 2388   381994
# 2389   364051
# 2390   660942

# %% [markdown]
# Findings: A deeper dive into unofficial release\_groups reveals a more serious issue: several are linked to multiple distinct TMDB films, often due to generic titles \(e\.g\., Limbo, Inside, Rage\) and title\-based matching\. In some cases, a single release\_group is mapped to as many as five different films\. This many\-to\-many ambiguity confirms that non\-Official statuses introduce structural contamination into the film–album spine\. Restricting the dataset to Official releases is therefore not just a cleanliness preference, but a necessary step to prevent cross\-film linkage errors\.

# %% [markdown]
# # III\. Deleting it from relevant tables

# %% [markdown]
# ### III\.1 Cleaning up the Album DataFrame

# %% [markdown]
# After confirming that non\-Official release groups introduce cross\-film ambiguity, the next step was to formalize their removal\. Rather than filtering implicitly downstream, we construct an explicit deletion list at the release\_group level\. This allows us to surgically remove problematic film–album links while preserving a clear audit trail of what was excluded and why\.

# %%
# 7) Create a deletion list you can apply later (wide_df, etc.)
# Each is a tuple: (release_group_mbid, tmdb_id)
unofficial_removed_links_rgid = list(
    unofficial_df.loc[:, ["release_group_id", "tmdb_id"]]
                    .dropna()
                    .drop_duplicates()
                    .itertuples(index=False, name=None) # Yields plain tuples of (release_group_id, tmdb_id) without index
)

# For these deletes, we only really need the release group id
unofficial_rgid_set = set(rg_id for rg_id, _tmdb in unofficial_removed_links_rgid)

print("Deletion list (release_group_id, tmdb_id):", len(unofficial_removed_links_rgid))
print("Unique release_group_id to delete from tracks:", len(unofficial_rgid_set))
print(unofficial_removed_links_rgid[:10])
# Out:
# Deletion list (release_group_id, tmdb_id): 173
# Unique release_group_id to delete from tracks: 143
# [(2755193, 307663), (1463713, 391700), (2596752, 615667), (2964242, 453395), (1045547, 454293), (1957589, 388202), (4259672, 551910), (3612486, 543343), (3294554, 894958), (3294554, 890116)]

# %% [markdown]
# Findings: This process identified 173 film–album link pairs corresponding to 143 unique release\_groups marked as non\-Official\. In practical terms, these represent structurally ambiguous or non\-canonical soundtrack mappings that would otherwise propagate into the track\-level dataset\. By isolating these release\_groups early, we prevent cross\-film contamination in the wide analytical layer and ensure that downstream listener metrics are attributed only to vetted, Official soundtrack albums\.

# %%
official_album_df = album_df[album_df["release_status_clean"] == "Official"].copy()

print("Rows before:", len(album_df))
print("Rows after (Official only):", len(official_album_df))

print("\nRelease status distribution (official df):")
display(official_album_df["release_status_clean"].value_counts(dropna=False))

official_album_df.to_csv(
    "./pipeline/3.2.Albums_official_df.csv",
    index=False
)
# Out:
# Rows before: 5209
# Rows after (Official only): 5036
#
# Release status distribution (official df):
# release_status_clean
# Official    5036
# Name: count, dtype: int64

# %% [markdown]
# Findings: Filtering to release\_status\_clean == "Official" reduced the album layer from 5,209 to 5,036 rows — a net removal of 173 records\. This confirms that non\-Official releases represented a relatively small but non\-trivial portion of the dataset \(~3%\)\. After filtering, the album spine consists entirely of Official releases, providing a cleaner and more defensible foundation for downstream track\- and listener\-level analysis\.

# %%
set(unofficial_rgid_set) - set(album_df.loc[album_df["release_status_clean"] != "Official", "release_group_id"])
# Out:
# set()

# %% [markdown]
# Findings: A sanity check confirmed that the set of release\_group IDs flagged as unofficial aligns perfectly with the rows removed by filtering to release\_status\_clean == "Official" \(empty set difference\)\. In other words, the applied filter and the earlier diagnostic deletion list are fully consistent\. This confirms that no unofficial release groups remain in the album spine and that the QA logic is internally coherent\.

# %% [markdown]
# ### III\.2 Cleaning up the Track DataFrame

# %% [markdown]
# Now, let's use the deletion list constructed in III\.1 to identify records to purge from the other tables\.

# %%
# Load the tracks dataframe

tracks_df = pd.read_csv("./pipeline/2.2.MUSICBRAINZ_mv_tmdb_soundtrack_track_spine_2015_2025.csv")
display(tracks_df.columns)
display(tracks_df.head())
# Out:
# Index(['tmdb_id', 'film_title', 'release_group_id', 'release_id',
#        'match_method', 'album_us_release_date', 'us_date_has_missing_month',
#        'us_date_has_missing_day', 'medium_id', 'disc_number', 'medium_format',
#        'track_id', 'track_number', 'track_title', 'track_length_ms',
#        'recording_id', 'recording_mbid', 'recording_title',
#        'recording_length_ms', 'recording_artist_credit',
#        'recording_first_release_year', 'recording_first_release_month',
#        'recording_first_release_day', 'isrcs_text', 'recording_tags_text',
#        'work_ids_text', 'work_titles_text', 'composer_names_text',
#        'lyricist_names_text'],
#       dtype='object')
#    tmdb_id    film_title  release_group_id  release_id           match_method  \
# 0   158852  Tomorrowland           1527294     1608979             imdb_exact
# 1   664425         Alone           4404592     5269969  title_contains_strict
# 2   675799         Alone           4404592     5269969  title_contains_strict
# 3   661950         Alone           4404592     5269969  title_contains_strict
# 4   664425         Alone           4404592     5269969  title_contains_strict
#
#   album_us_release_date us_date_has_missing_month us_date_has_missing_day  \
# 0            2015-06-09                     False                   False
# 1                   NaN                       NaN                     NaN
# 2                   NaN                       NaN                     NaN
# 3                   NaN                       NaN                     NaN
# 4                   NaN                       NaN                     NaN
#
#    medium_id  disc_number  medium_format  track_id  track_number  track_title  \
# 0    1692109            1  Digital Media  18687683            13  Frank Frank
# 1    5726478            1           CD-R  54208593             4      Isolate
# 2    5726478            1           CD-R  54208593             4      Isolate
# 3    5726478            1           CD-R  54208593             4      Isolate
# 4    5726478            1           CD-R  54208601            12    Screamers
#
#    track_length_ms  recording_id                        recording_mbid  \
# 0          78000.0      17796063  cb79d078-c57b-46a3-a09b-e3903e73aeb8
# 1         140000.0      43561702  21fd6fb4-b461-4bd3-a12d-aaa01eee0d8d
# 2         140000.0      43561702  21fd6fb4-b461-4bd3-a12d-aaa01eee0d8d
# 3         140000.0      43561702  21fd6fb4-b461-4bd3-a12d-aaa01eee0d8d
# 4         162000.0      43561710  23437721-6ac1-44a1-9e92-59fb1a950fa5
#
#   recording_title  recording_length_ms recording_artist_credit  \
# 0     Frank Frank              78000.0       Michael Giacchino
# 1         Isolate             140000.0       Frederik Wiedmann
# 2         Isolate             140000.0       Frederik Wiedmann
# 3         Isolate             140000.0       Frederik Wiedmann
# 4       Screamers             162000.0       Frederik Wiedmann
#
#    recording_first_release_year  recording_first_release_month  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    recording_first_release_day    isrcs_text recording_tags_text  \
# 0                          NaN  USWD11570549                 NaN
# 1                          NaN           NaN                 NaN
# 2                          NaN           NaN                 NaN
# 3                          NaN           NaN                 NaN
# 4                          NaN           NaN                 NaN
#
#   work_ids_text work_titles_text composer_names_text lyricist_names_text
# 0      14179222      Frank Frank   Michael Giacchino                 NaN
# 1      14876176          Isolate   Frederik Wiedmann                 NaN
# 2      14876176          Isolate   Frederik Wiedmann                 NaN
# 3      14876176          Isolate   Frederik Wiedmann                 NaN
# 4      14876184        Screamers   Frederik Wiedmann                 NaN

# %%
# Calculate the length BEFORE the deletion
tracks_before = len(tracks_df)

# Delete rows that contain the release group ids in the delete list
is_unofficial_track = tracks_df["release_group_id"].isin(unofficial_rgid_set)
deleted_track_ct = int(is_unofficial_track.sum())

tracks_official_df = tracks_df.loc[~is_unofficial_track].copy()

print(f"Tracks before: {tracks_before:,}")
print(f"Tracks deleted: {deleted_track_ct:,}")
print(f"Tracks after:  {len(tracks_official_df):,}")

tracks_official_df.to_csv(
    "./pipeline/3.2.Tracks_official_df.csv",
    index=False
)
# Out:
# Tracks before: 85,842
# Tracks deleted: 2,968
# Tracks after:  82,874

# %%
# For completeness, let's upload artist_df even though we don't need to deletion on it and save the output into
# the pipeline

artist_df = pd.read_csv("./pipeline/2.2.MUSICBRAINZ_mv_tmdb_soundtrack_artist_spine_2015_2025.csv")
artist_df.to_csv(
    "./pipeline/3.2.Artists_official_df.csv",
    index=False
)

# %% [markdown]
# ### III\.3 Cleaning up the Wide DataFrame

# %%
# Load the wide dataframe

wide_df = pd.read_csv("./pipeline/2.2.MUSICBRAINZ_mv_tmdb_soundtrack_wide_track_2015_2025.csv")
display(wide_df.columns)
display(wide_df.head())
# Out:
# /tmp/ipykernel_241/1985245225.py:3: DtypeWarning: Columns (45,58,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   wide_df = pd.read_csv("./pipeline/2.2.MUSICBRAINZ_mv_tmdb_soundtrack_wide_track_2015_2025.csv")
# Index(['tmdb_id', 'film_title', 'film_adult', 'film_runtime_min',
#        'film_genres', 'film_rating', 'film_vote_count', 'film_mpaa_rating',
#        'film_original_title', 'film_language_name', 'film_imdb_id',
#        'film_wikidata_id', 'film_countries', 'film_year', 'film_release_date',
#        'film_popularity', 'film_budget', 'film_revenue', 'film_studios',
#        'film_director', 'film_soundtrack_composer_raw', 'film_top_cast',
#        'film_keywords', 'film_ingested_at', 'release_group_id',
#        'release_group_mbid', 'release_id', 'release_mbid', 'album_title',
#        'rg_primary_type', 'rg_secondary_types', 'match_method',
#        'album_soundtrack_type', 'album_notes', 'album_matched_at',
#        'album_us_release_date', 'album_us_release_year',
#        'album_us_release_month_min_observed',
#        'album_us_release_day_min_observed', 'us_date_has_missing_month',
#        'us_date_has_missing_day', 'us_any_event_missing_month',
#        'us_any_event_missing_day', 'release_title', 'release_status',
#        'release_packaging', 'barcode', 'release_language', 'release_script',
#        'release_comment', 'rg_tags_text', 'release_tags_text', 'label_names',
#        'label_mbids', 'label_tags_text', 'rg_rating', 'rg_rating_count',
#        'release_meta_date_added', 'release_meta_info_url',
#        'release_meta_amazon_asin', 'release_meta_cover_art_presence',
#        'album_artist_ids_text', 'album_artist_names_text',
#        'album_artist_mbids_text', 'album_artist_types_text',
#        'album_artist_max_film_ct_in_spine',
#        'album_artist_max_soundtrack_rg_ct_in_spine', 'medium_id',
#        'disc_number', 'medium_format', 'track_id', 'track_number',
#        'track_title', 'track_length_ms', 'recording_id', 'recording_mbid',
#        'recording_title', 'recording_length_ms', 'recording_artist_credit',
#        'isrcs_text', 'recording_first_release_year',
#        'recording_first_release_month', 'recording_first_release_day',
#        'recording_tags_text', 'work_ids_text', 'work_titles_text',
#        'composer_names_text', 'lyricist_names_text'],
#       dtype='object')
#    tmdb_id         film_title  film_adult  film_runtime_min       film_genres  \
# 0  1027160  Alone in the Dark       False                90  Horror, Thriller
# 1  1027160  Alone in the Dark       False                90  Horror, Thriller
# 2   322855          Shakedown       False                72       Documentary
# 3   322855          Shakedown       False                72       Documentary
# 4   322855          Shakedown       False                72       Documentary
#
#    film_rating  film_vote_count film_mpaa_rating film_original_title  \
# 0        4.769               13               NR   Alone in the Dark
# 1        4.769               13               NR   Alone in the Dark
# 2        5.038               14               NR           Shakedown
# 3        5.038               14               NR           Shakedown
# 4        5.038               14               NR           Shakedown
#
#   film_language_name film_imdb_id film_wikidata_id            film_countries  \
# 0            English   tt21859110              NaN  United States of America
# 1            English   tt21859110              NaN  United States of America
# 2            English    tt1794951        Q89668506  United States of America
# 3            English    tt1794951        Q89668506  United States of America
# 4            English    tt1794951        Q89668506  United States of America
#
#    film_year film_release_date  film_popularity  film_budget  film_revenue  \
# 0       2022        2022-10-07           0.1425            0             0
# 1       2022        2022-10-07           0.1425            0             0
# 2       2018        2018-02-17           0.4010            0             0
# 3       2018        2018-02-17           0.4010            0             0
# 4       2018        2018-02-17           0.4010            0             0
#
#                                     film_studios    film_director  \
# 0  The Ninth House, MarVista Entertainment, Tubi  Brant Daugherty
# 1  The Ninth House, MarVista Entertainment, Tubi  Brant Daugherty
# 2                                         MEMORY  Leilah Weinraub
# 3                                         MEMORY  Leilah Weinraub
# 4                                         MEMORY  Leilah Weinraub
#
#   film_soundtrack_composer_raw  \
# 0           Christopher French
# 1           Christopher French
# 2                    Tim Dewit
# 3                    Tim Dewit
# 4                    Tim Dewit
#
#                                        film_top_cast  \
# 0  Novi Brown, Christopher Bencomo, Kimberly Daug...
# 1  Novi Brown, Christopher Bencomo, Kimberly Daug...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        film_keywords  \
# 0                   stalker, survival, home invasion
# 1                   stalker, survival, home invasion
# 2  strip club, los angeles, california, woman dir...
# 3  strip club, los angeles, california, woman dir...
# 4  strip club, los angeles, california, woman dir...
#
#                 film_ingested_at  release_group_id  \
# 0  2026-01-19 01:36:06.359 -0500            135013
# 1  2026-01-19 01:36:06.359 -0500            135013
# 2  2026-01-19 01:36:05.812 -0500            165359
# 3  2026-01-19 01:36:05.812 -0500            165359
# 4  2026-01-19 01:36:05.812 -0500            165359
#
#                      release_group_mbid  release_id  \
# 0  fb75d93e-d99d-33c7-bd60-80e2228651d3      949340
# 1  fb75d93e-d99d-33c7-bd60-80e2228651d3      949340
# 2  65314ddb-ab05-314e-bef9-b1372d825266      893204
# 3  65314ddb-ab05-314e-bef9-b1372d825266      893204
# 4  65314ddb-ab05-314e-bef9-b1372d825266      893204
#
#                            release_mbid        album_title rg_primary_type  \
# 0  40b79a4f-ca31-48fe-91a9-019c3c4eab5e  Alone in the Dark             NaN
# 1  40b79a4f-ca31-48fe-91a9-019c3c4eab5e  Alone in the Dark             NaN
# 2  7003024e-dea5-488a-8253-8b8042fc9eb9          Shakedown           Album
# 3  7003024e-dea5-488a-8253-8b8042fc9eb9          Shakedown           Album
# 4  7003024e-dea5-488a-8253-8b8042fc9eb9          Shakedown           Album
#
#   rg_secondary_types           match_method album_soundtrack_type  \
# 0         Soundtrack  title_contains_strict               unknown
# 1         Soundtrack  title_contains_strict               unknown
# 2         Soundtrack  title_contains_strict               unknown
# 3         Soundtrack  title_contains_strict               unknown
# 4         Soundtrack  title_contains_strict               unknown
#
#    album_notes               album_matched_at album_us_release_date  \
# 0          NaN  2026-01-25 03:07:30.754 -0500                   NaN
# 1          NaN  2026-01-25 03:07:30.754 -0500                   NaN
# 2          NaN  2026-01-25 03:07:30.754 -0500                   NaN
# 3          NaN  2026-01-25 03:07:30.754 -0500                   NaN
# 4          NaN  2026-01-25 03:07:30.754 -0500                   NaN
#
#    album_us_release_year  album_us_release_month_min_observed  \
# 0                    NaN                                  NaN
# 1                    NaN                                  NaN
# 2                    NaN                                  NaN
# 3                    NaN                                  NaN
# 4                    NaN                                  NaN
#
#    album_us_release_day_min_observed us_date_has_missing_month  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
#
#   us_date_has_missing_day us_any_event_missing_month us_any_event_missing_day  \
# 0                     NaN                        NaN                      NaN
# 1                     NaN                        NaN                      NaN
# 2                     NaN                        NaN                      NaN
# 3                     NaN                        NaN                      NaN
# 4                     NaN                        NaN                      NaN
#
#                 release_title release_status release_packaging  barcode  \
# 0  Alone in the Dark (disc 2)       Official               NaN      NaN
# 1  Alone in the Dark (disc 2)       Official               NaN      NaN
# 2                   Shakedown       Official               NaN      NaN
# 3                   Shakedown       Official               NaN      NaN
# 4                   Shakedown       Official               NaN      NaN
#
#   release_language release_script release_comment rg_tags_text  \
# 0          English          Latin             NaN          NaN
# 1          English          Latin             NaN          NaN
# 2          English          Latin             NaN          NaN
# 3          English          Latin             NaN          NaN
# 4          English          Latin             NaN          NaN
#
#   release_tags_text label_names label_mbids label_tags_text  rg_rating  \
# 0               NaN         NaN         NaN             NaN        NaN
# 1               NaN         NaN         NaN             NaN        NaN
# 2               NaN         NaN         NaN             NaN        NaN
# 3               NaN         NaN         NaN             NaN        NaN
# 4               NaN         NaN         NaN             NaN        NaN
#
#    rg_rating_count        release_meta_date_added release_meta_info_url  \
# 0              NaN  2003-07-01 07:09:43.921 -0400                   NaN
# 1              NaN  2003-07-01 07:09:43.921 -0400                   NaN
# 2              NaN  2003-12-01 14:28:24.749 -0500                   NaN
# 3              NaN  2003-12-01 14:28:24.749 -0500                   NaN
# 4              NaN  2003-12-01 14:28:24.749 -0500                   NaN
#
#   release_meta_amazon_asin release_meta_cover_art_presence  \
# 0                      NaN                          absent
# 1                      NaN                          absent
# 2                      NaN                          absent
# 3                      NaN                          absent
# 4                      NaN                          absent
#
#   album_artist_ids_text album_artist_names_text  \
# 0                 79164         Philippe Vachey
# 1                 79164         Philippe Vachey
# 2                     1         Various Artists
# 3                     1         Various Artists
# 4                     1         Various Artists
#
#                 album_artist_mbids_text album_artist_types_text  \
# 0  31056e50-d37d-461d-9c56-c1e2ad5ecf58                  Person
# 1  31056e50-d37d-461d-9c56-c1e2ad5ecf58                  Person
# 2  89ad4ac3-39f7-470e-963a-56509c546377                   Other
# 3  89ad4ac3-39f7-470e-963a-56509c546377                   Other
# 4  89ad4ac3-39f7-470e-963a-56509c546377                   Other
#
#    album_artist_max_film_ct_in_spine  \
# 0                                  1
# 1                                  1
# 2                                469
# 3                                469
# 4                                469
#
#    album_artist_max_soundtrack_rg_ct_in_spine  medium_id  disc_number  \
# 0                                           1     949340            1
# 1                                           1     949340            1
# 2                                         460     893204            1
# 3                                         460     893204            1
# 4                                         460     893204            1
#
#    medium_format  track_id  track_number              track_title  \
# 0  Mixed Mode CD   1106869             2  Alone in the Dark Theme
# 1  Mixed Mode CD   1106868             1             [data track]
# 2            NaN   1410336            12                     Gloc
# 3            NaN   1410325             1               Move It Up
# 4            NaN   1410326             2             Party People
#
#    track_length_ms  recording_id                        recording_mbid  \
# 0         223066.0       1298993  bcb316f0-3f28-4a94-a087-db78d3a51fde
# 1        3620786.0       1298992  af02c70c-6c69-4c62-9f34-68a898c98402
# 2         186106.0       1665130  fe0a2712-2fee-4f41-9901-1cff2cf91e77
# 3         158480.0       1665119  a48f1589-33cd-457f-978c-f8ef9a818bab
# 4         202053.0       1665120  94b1c5ef-adeb-467f-83c3-06c4fa8cfb93
#
#            recording_title  recording_length_ms recording_artist_credit  \
# 0  Alone in the Dark Theme             223066.0         Philippe Vachey
# 1             [data track]            3620786.0         Philippe Vachey
# 2                     Gloc             186106.0               Buc Fifty
# 3               Move It Up             158480.0          Rob the Viking
# 4             Party People             202053.0              Son Doobie
#
#   isrcs_text  recording_first_release_year  recording_first_release_month  \
# 0        NaN                           NaN                            NaN
# 1        NaN                           NaN                            NaN
# 2        NaN                           NaN                            NaN
# 3        NaN                           NaN                            NaN
# 4        NaN                           NaN                            NaN
#
#    recording_first_release_day recording_tags_text work_ids_text  \
# 0                          NaN                 NaN           NaN
# 1                          NaN                 NaN           NaN
# 2                          NaN                 NaN           NaN
# 3                          NaN                 NaN           NaN
# 4                          NaN                 NaN           NaN
#
#   work_titles_text composer_names_text lyricist_names_text
# 0              NaN                 NaN                 NaN
# 1              NaN                 NaN                 NaN
# 2              NaN                 NaN                 NaN
# 3              NaN                 NaN                 NaN
# 4              NaN                 NaN                 NaN

# %%
# Calculate the length BEFORE the deletion
wide_before = len(wide_df)

# Delete rows that contain the release group ids in the delete list
is_unofficial_wide = wide_df["release_group_id"].isin(unofficial_rgid_set)
deleted_wide_ct = int(is_unofficial_wide.sum())

wide_official_df = wide_df.loc[~is_unofficial_wide].copy()

print(f"Records before: {wide_before:,}")
print(f"Records deleted: {deleted_wide_ct:,}")
print(f"Records after:  {len(wide_official_df):,}")

wide_official_df.to_csv(
    "./pipeline/3.2.Wide_official_df.csv",
    index=False
)
# Out:
# Records before: 85,842
# Records deleted: 2,968
# Records after:  82,874

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b124131d-2024-4253-bb46-8043aed4b78f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
